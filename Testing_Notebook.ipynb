# %%
from modelPipelines import LSTMPipeline, Conv1DPipeline, AutoencoderPipeline
import yaml

# %%
config_path='/Users/flore/Documents/01_Forschung/09_Coding.nosync/07_Tool_wear_DA/tool-wear-domain-adaption/nasa_notebooks/config_n_vs_2/config_test_2_5.yaml'
with open(config_path, "r") as f:
        config = yaml.safe_load(f)
pipe=AutoencoderPipeline(config)

# %%
pipe.run()

# %%
data['wear_norm'].hist(bins=30)

# %%
data['CaseID']
